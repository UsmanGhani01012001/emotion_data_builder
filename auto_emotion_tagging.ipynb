# %%
import pandas as pd
import requests
import time
import random
import re

api_key = "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"

headers = {
    "Authorization": f"Bearer {api_key}",
    "Content-Type": "application/json"
}

EMOTION_LIST = ["joy", "anger", "fear", "nostalgia", "sad", "obsession", "sexual", "hope", "calm", "tender", "violence", "power"]
EMOTION_SET = set(EMOTION_LIST)

def extract_emotions_only(text):
    # Extract all valid emotion words in order, remove duplicates
    found = re.findall(r'\b(?:' + '|'.join(EMOTION_LIST) + r')\b', text.lower())
    found = list(dict.fromkeys(found))  # deduplicate, preserve order
    if 2 <= len(found) <= 4:
        return ', '.join(found)
    else:
        return "error"

def is_valid_emotion_output(output):
    emotions = [e.strip() for e in output.lower().split(",")]
    return 2 <= len(emotions) <= 4 and all(e in EMOTION_SET for e in emotions)

def get_lyrics_emotions(lyrics, max_retries=7):
    prompt = f"""
Given the following song lyrics, label them with the most dominant emotions.
Use only the following emotion labels: joy, anger, fear, nostalgia, sad, obsession, sexual, hope, calm, tender, violence, power.
Return the emotions separated by commas. The number of labels must be 2 to 4.
Do not provide any explanation. Only return the emotion labels.

Example 1:
Lyrics:
I miss the days we danced all night under the stars, now I'm lost and alone.
Emotions:
nostalgia, sad

Example 2:
Lyrics:
You said you'd love me forever, now I'm burning with rage.
Emotions:
anger, obsession

Lyrics:
{lyrics}

Emotions:
"""
    data = {
        "model": "llama3-70b-8192",
        "messages": [{"role": "user", "content": prompt}],
        "temperature": 0.2
    }

    backoff = 2
    retries = 0

    while retries < max_retries:
        try:
            response = requests.post(
                "https://api.groq.com/openai/v1/chat/completions",
                headers=headers,
                json=data
            )
            if response.status_code == 200:
                raw_output = response.json()["choices"][0]["message"]["content"].strip()
                extracted = extract_emotions_only(raw_output)
                if extracted != "error" and is_valid_emotion_output(extracted):
                    return extracted
                else:
                    # Retry once if invalid output format
                    retries += 1
                    print(f"⚠️ Invalid output format, retrying {retries}/{max_retries}...")
                    time.sleep(random.uniform(1, 2))
                    continue

            elif response.status_code == 429:
                retries += 1
                try:
                    msg = response.json()["error"]["message"]
                    wait_time = float(msg.split("try again in ")[1].split("s")[0])
                except Exception:
                    wait_time = backoff

                jitter = random.uniform(0.75, 1.25)
                sleep_time = max(wait_time, backoff) * jitter
                print(f"⚠️ Rate limit hit. Retry {retries}/{max_retries}. Waiting {sleep_time:.2f} seconds...")
                time.sleep(sleep_time)
                backoff = min(backoff * 1.5, 30)

            else:
                print(f"API error {response.status_code}: {response.text}")
                return "error"

        except Exception as e:
            print(f"Request failed: {e}")
            return "error"

    print(f"⚠️ Failed to get valid response after {max_retries} retries, skipping lyric.")
    return "error"


# Load CSV
df = pd.read_csv("good.csv", encoding='ISO-8859-1')

if 'lyrics' not in df.columns:
    raise ValueError("CSV must have a column named 'lyrics'.")

if "emotions" not in df.columns:
    df["emotions"] = ""

# Loop over rows
for i, row in df.iterrows():
    lyrics = row["lyrics"]
    print(f"\nLyrics {i+1}/{len(df)}:\n{lyrics[:300]}...")

    emotions = get_lyrics_emotions(lyrics)
    df.at[i, "emotions"] = emotions

    print("Emotions:", emotions)
    print("-" * 60)

    if (i + 1) % 10 == 0:
        df.to_csv("labeled_lyrics_progress.csv", index=False)
        print(f"Progress saved at song {i+1}.")

    delay = random.uniform(6, 10)
    print(f"Waiting {delay:.2f} seconds before next request...")
    time.sleep(delay)

# Save final results
df.to_csv("labeled_lyrics_final.csv", index=False)
print("\n✅ Done! Emotions labeled and saved to labeled_lyrics_final.csv")
# Out:
# Lyrics 1/897:
# Oh my god, did I just say that out loud? Should've known this was the kind of place That that sort of thing just wasn't allowed Should've known by the color of the drapes (Oh, my bad, venetian blinds) What the hell was I thinking saying exactly what's on my mind? But I won't deny I got a dirty mouth...
# C:\Users\LAPTOP INSIDE\AppData\Local\Temp\ipykernel_12604\316235477.py:123: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'anger, power' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[i, "emotions"] = emotions
# Emotions: anger, power
# ------------------------------------------------------------
# Waiting 9.50 seconds before next request...
#
# Lyrics 2/897:
# [Verse 1] Remember when I called you on the telephone? You were so far away It was raining in New York, did I forget to say? It was later than I wanted it to be On an early summer's night The kind where you can't help but feel alive and free And I told you "From here on out, it's just you and me"  [...
# Emotions: hope, joy
# ------------------------------------------------------------
# Waiting 9.89 seconds before next request...
#
# Lyrics 3/897:
# [Verse 1] Calling me like I got something to say You thought wrong, but you do it anyway How's it been? Oh, not much, same for me, please go away I can put it on if that's what you want You'd like to get together, but I'd rather not Calls to mind a simpler time that who gave a shit forgot  [Pre-Chor...
# Emotions: anger, obsession
# ------------------------------------------------------------
# Waiting 8.22 seconds before next request...
#
# Lyrics 4/897:
# One drink, two drinks, three drinks, four She had eyes that I couldn't ignore Chatted her up out on the dance floor She was out of cigarettes so I walked her to the store  Skirt pulled up, pushed up against the wall But she pauses just the take a call Joanne says "girl, what the fuck are you doing? ...
# Emotions: sexual, power
# ------------------------------------------------------------
# Waiting 6.66 seconds before next request...
#
# Lyrics 5/897:
# I'll take anyone New York to London They say brave men run to the sound of fun  Fixing to hit you Fixing to hit you Fixing to hit you Fixing to hit you  Ooh, I'll take anyone New York to London They say brave men run to the sound of fun  You'd better make You'd better make You'd better make your bed...
# Emotions: power, joy
# ------------------------------------------------------------
# Waiting 7.74 seconds before next request...
#
# Lyrics 6/897:
# All night All night All night ('Til the break of dawn) All night ('Til the break of dawn)  There I was, nearly November Moon shone bright, barely a sliver While across my mind ran all the things that I never Now I like to think that I'm nobody's prisoner I wasn't sure, but I sure was a listener When...
# Emotions: obsession, power
# ------------------------------------------------------------
# Waiting 6.75 seconds before next request...
#
# Lyrics 7/897:
# We all claim purple like its the purpose Though we far from the Urkel life Nerd clownin' but clownin' is for the circus, right? Well, that's for cert, Cuz, umm But what about sir cousin whose circumstance to be dickheads? Knife cut 'em, he circumcised Officers come in sizes, they bring the cop out Y...
# Emotions: anger, power
# ------------------------------------------------------------
# Waiting 6.12 seconds before next request...
#
# Lyrics 8/897:
# [Verse 1] Hey, baby Hey maybe I'm forgetting to say That I stayed with you because I wanted to And you were so very kind You listened to my troubling mind Said "Leave all that hist'ry behind And deal with life as it's offered to you."  [Verse 2] Hey, honey You know we'll treat each other just fine I...
# Emotions: tender, hope
# ------------------------------------------------------------
# Waiting 9.91 seconds before next request...
#
# Lyrics 9/897:
# [Verse 1] He is in the blue distance He is getting nearer She is in the blue distance She is getting so clear I don? know where they came from I don? know how we got here I just turned my back and suddenly you were here  [Verse 2] Oh boy, sometimes it seems like it takes forever And then with your f...
# Emotions: nostalgia, tender
# ------------------------------------------------------------
# Waiting 6.26 seconds before next request...
#
# Lyrics 10/897:
# [Verse 1: Elena] It's holiday time The most special of seasons So come gather round To remember the reason It's not all the gifts The food or decorations But the spirit of love That marks this celebration  [Chorus: Elena, Elena & Gabe] So come walk with me Sing along and you'll see On this holiday L...
# Emotions: joy, hope, tender
# ------------------------------------------------------------
# Progress saved at song 10.
# Waiting 9.23 seconds before next request...
#
# Lyrics 11/897:
# [The docks. Sailors, whores and their customers, pimps, etc. Fantine wanders  in.]        Sailors    I smell women    Smell 'em in the air    Think I'll drop my anchor    In that harbor over there    Lovely ladies    Smell 'em through the smoke    Seven days at sea    Can make you hungry for a poke ...
# Emotions: sexual, sad
# ------------------------------------------------------------
# Waiting 7.00 seconds before next request...
#
# Lyrics 12/897:
# [Marius and Cosette lead a wedding procession.]        Chorus    Ring out the bells upon this day of days!    May all the angels of the Lord above    In jubilation sing their songs of praise!    And crown this blessed time with peace and love.        [The procession becomes a dancing celebration. A ...
# Emotions: joy, hope, power
# ------------------------------------------------------------
# Waiting 8.39 seconds before next request...
#
# Lyrics 13/897:
# Bingo and Rolly Couple of puppies They bark and chase and chew And there's a guy named Bob who makes up inventions A couple puppies can use But when Bob's away (See you latter pup's) The pups will play On a mission around the world tryin' save the day Pup-pup-pup Puppy dog pals Pup-pup-pup Puppy dog...
# Emotions: joy, calm
# ------------------------------------------------------------
# Waiting 7.05 seconds before next request...
#
# Lyrics 14/897:
# [Verse 1] As I walk through the valley where I harvest my grain I take a look at my wife and realize she's very plain But that's just perfect for an Amish like me You know, I shun fancy things like electricity At 4:30 in the mornin' I'm milkin' cows Jebediah feeds the chickens and Jacob plows, fool ...
# Emotions: joy, calm, tender
# ------------------------------------------------------------
# Waiting 8.67 seconds before next request...
#
# Lyrics 15/897:
# [Intro] Everybody shut up! (Woo!) Everyone listen up! Hey, hey, hey Hey, hey, hey (Uh, woo!) Hey, hey, hey (Woo!)  [Verse 1] If you can't write in the proper way (Woo!) If you don't know how to conjugate (Woo!) Hey, maybe you flunked that class (Hey, hey, hey) And maybe now you find (Hey, hey, hey) ...
# Emotions: anger, power
# ------------------------------------------------------------
# Waiting 7.22 seconds before next request...
#
# Lyrics 16/897:
# [Chorus] They see me mowin' my front lawn I know they're all thinking I'm so white and nerdy Think I'm just too white and nerdy Think I'm just too white and nerdy Can't you see I'm white and nerdy? Look at me, I'm white and nerdy I wanna roll with the gangstas But so far they all think I'm too white...
# Emotions: joy, calm
# ------------------------------------------------------------
# Waiting 8.92 seconds before next request...
#
# Lyrics 17/897:
# [Verse 1] Aquarius! There's travel in your future when your tongue Freezes to the back of a speeding bus Fill that void in your pathetic life By playing Whack-A-Mole seventeen hours a day  Pisces! Try to avoid any Virgos or Leos With the Ebola virus You are the true Lord of the Dance No matter what ...
# Emotions: joy, power, violence
# ------------------------------------------------------------
# Waiting 8.94 seconds before next request...
#
# Lyrics 18/897:
# [Verse 1: "Alexander Hamilton"] How does a bastard, orphan, son of a whore and a Scotsman, dropped in the middle of a forgotten Spot in the Caribbean by providence, impoverished, in squalor Grow up to be a hero and a scholar? The ten-dollar Founding Father without a father Got a lot farther by worki...
# Emotions: hope, power
# ------------------------------------------------------------
# Waiting 6.87 seconds before next request...
#
# Lyrics 19/897:
# [Verse 1] I never seem to finish all my food I always get a doggie bag from the waiter So I just keep what's still unchewed And I take it home, save it for later  [Pre-Chorus 1] But then I deal with fungal rot, bacterial formation Microbes, enzymes, mold, and oxidation I don't care; I've got a secre...
# Emotions: power, obsession
# ------------------------------------------------------------
# Waiting 6.49 seconds before next request...
#
# Lyrics 20/897:
# I, man, am Regal, a German am I Never odd or even If I had a Hi-Fi Madam, I'm Adam Too hot to hoot No lemons no melon Too bad I hid a boot Lisa Bonet ate no basil Warsaw was raw Was it a car or a cat I saw?  Rise to vote, sir Do geese see God? Do nine men Interpret? Nine men I nod Rats live on no ev...
# Emotions: power, calm
# ------------------------------------------------------------
# Progress saved at song 20.
# Waiting 7.22 seconds before next request...
#
# Lyrics 21/897:
# Veren zol fun dir a blintse  [Intro] How ya doin', Bernie? (Oy vey! Oy vey!) How ya doin', Bernie? (Oy vey! Oy vey!) How ya doin', Bernie? (Oy vey! Oy vey!) And all the goyim say I'm pretty fly for a rabbi  Meccha leccha hi, meccha hiney hiney ho  [Verse 1] Our temple's had a fair share of rabbis in...
# Emotions: joy, hope, calm
# ------------------------------------------------------------
# Waiting 8.46 seconds before next request...
#
# Lyrics 22/897:
# [Verse 1] First things first, I'm a craftsman (Craftsman) Remodelling is my only passion (It's my passion) And I'm the greatest in the business Want referrals, yo My client?e will bear you witness (Right, right) I can help when your door jamb sticks (heh?) There is nothing in the world I can't fix (...
# Emotions: joy, power
# ------------------------------------------------------------
# Waiting 7.74 seconds before next request...
#
# Lyrics 23/897:
# [Verse 1] I've never been The one to raise my hand That was not me And now that's who I am Because of you I am standing tall  [Verse 2] My heart is full Of endless gratitude You were the one The one to guide me through Now I can see And I believe It's only just beginning  [Chorus] This is what we dr...
# Emotions: hope, joy
# ------------------------------------------------------------
# Waiting 6.34 seconds before next request...
#
# Lyrics 24/897:
# [Verse 1] Down in the workshop, all the elves were making toys For the good Gentile girls and the good Gentile boys When the boss busted in, nearly scared them half to death Had a rifle in his hands and cheap whiskey on his breath From his beard to his boots, he was covered with ammo Like a big fat ...
# Emotions: violence, anger
# ------------------------------------------------------------
# Waiting 8.27 seconds before next request...
#
# Lyrics 25/897:
# [Verse 1] We've been together for so very long But now things are changing, oh, I wonder what's wrong Seems you don't want me around The passion is gone and the flame's died down I guess I lost a little bit of self-esteem That time that you made it with the whole hockey team You used to think I was ...
# Emotions: anger, violence
# ------------------------------------------------------------
# Waiting 8.86 seconds before next request...
#
# Lyrics 26/897:
# La-la-la-lasagna You want-a some-a lasagna magnifico Or a-maybe spaghetti Ay, you supper's a-ready now, here you go Mama mia bambino Mama mia bambino 'Samatta you, 'samatta you, 'samatta you  You should-a taste my lasagna Ay, you no like-a lasagna That's okay too How about-a calzone Some-a nice mine...
# Emotions: joy, calm
# ------------------------------------------------------------
# Waiting 9.18 seconds before next request...
#
# Lyrics 27/897:
# [Verse 1] Jillian was her name She was sweeter than aspartame Her kisses reconfigured my DNA And after that I never was the same And I loved her even more Than Marlon Brando loved souffle She was gorgeous, she was charming Yeah, she was perfect in every way Except she was always using the word "infe...
# Emotions: joy, obsession
# ------------------------------------------------------------
# Waiting 7.38 seconds before next request...
#
# Lyrics 28/897:
# ["Last Resort" by Papa Roach] Cut my life into pieces This is my last resort Suffocation: No breathing Don't give a **** if I cut my arm bleeding This is my Last Resort Cause now I'm losing my sight Losing my mind, wish somebody'd tell me I'm fine Losing my sight, losing my mind Wish somebody'd tell...
# Emotions: anger, power
# ------------------------------------------------------------
# Waiting 6.57 seconds before next request...
#
# Lyrics 29/897:
# [Verse 1] Tuesday morning, 8:15 I was riding to work on the Jackson Park Express Seemed like any other day Then my whole world changed In a way I never could have guessed Cause she walked in Took the seat right across the aisle I knew we had a special connection The second I saw her smile  She smile...
# Emotions: joy, obsession, sexual
# ------------------------------------------------------------
# Waiting 7.42 seconds before next request...
#
# Lyrics 30/897:
# [Verse 1] We must all efficiently Operationalize our strategies Invest in world-class technology And leverage our core competencies In order to holistically administrate Exceptional synergy We'll set a brand trajectory Using management philosophy Advance our market share vis-·vis Our proven methodol...
# Emotions: power, hope
# ------------------------------------------------------------
# Progress saved at song 30.
# Waiting 8.48 seconds before next request...
#
# Lyrics 31/897:
# [Verse 1] Your sports team is vastly inferior That simple fact is plainly obvious to see We?e gonna kick your collective posterior Of course you realize we?e speaking figuratively Our stats are thoroughly impressive Our coach really has the Midas touch Our players are fast and strong and brave And y...
# Emotions: anger, power
# ------------------------------------------------------------
# Waiting 7.03 seconds before next request...
#
# Lyrics 32/897:
# (Well,) I'm not the brightest crayon in the box Everyone says I'm dumber than a bag of rocks I barely even know... how to put on my own pants! But I'm a genius in France (yeah), genius in France, genius in France!  Hoom chaka laka Hoom chaka laka Hoom chaka  I may not be the sharpest hunk of cheese ...
# Emotions: joy, power
# ------------------------------------------------------------
# Waiting 7.96 seconds before next request...
#
# Lyrics 33/897:
# [Chicken Dance Instrumental]  ["Let's Get it Started" by Black Eyed Peas] Let's get it started (ha) Let's get it started (in here) Let's get it started (ha) Let's get it started (in here) Let's get it started (ha) Let's get it started (in here) And the bass keeps runnin' runnin' And runnin' runnin' ...
# Emotions: joy, power, sexual
# ------------------------------------------------------------
# Waiting 7.94 seconds before next request...
#
# Lyrics 34/897:
# [Verse 1] It's Christmas at ground zero There's music in the air The sleigh bells are ringing, and the carolers are singing While the air-raid sirens blare  [Verse 2] It's Christmas at ground zero The button has been pressed The radio just let us know That this is not a test  [Chorus 1] Everywhere t...
# Emotions: fear, violence
# ------------------------------------------------------------
# Waiting 8.09 seconds before next request...
#
# Lyrics 35/897:
# ["Wannabe" by Spice Girls] Yo, I'll tell you what I want What I really really want So tell us what you want What you really really want Yo, I'll tell you what I want What I really really want So tell us what you want What you really really want I wanna ha I wanna ha I wanna ha I wanna really wanna r...
# ⚠️ Invalid output format, retrying 1/7...
# ⚠️ Invalid output format, retrying 2/7...
# ⚠️ Invalid output format, retrying 3/7...
# ⚠️ Invalid output format, retrying 4/7...
# ⚠️ Invalid output format, retrying 5/7...
# ⚠️ Invalid output format, retrying 6/7...
# ⚠️ Rate limit hit. Retry 7/7. Waiting 4.61 seconds...
# ⚠️ Failed to get valid response after 7 retries, skipping lyric.
# Emotions: error
# ------------------------------------------------------------
# Waiting 8.04 seconds before next request...
#
# Lyrics 36/897:
# [Intro] Sometimes I feel, like I need a vacation Sometimes I feel, like I wanna go To the city of cavemen, the city of Bedrock I'd be a Flintstone, now I'll tell you why  [Verse 1] Well, I've got, I've got a woman named Wilma Well, I've got, I've got a baby named Pebbles Well, I've got, I've got a d...
# Emotions: joy, calm
# ------------------------------------------------------------
# Waiting 8.91 seconds before next request...
#
# Lyrics 37/897:
# I don't have a library card But do you mind if I check you out? I like your skeletal structure, baby You're an ectomorph, no doubt Your face is real symmetrical And your nostrils are so nice I wish that I was cross-eyed, girl So I could see you twice  Girl, you smell like Fritos That's why I'm givin...
# Emotions: sexual, obsession
# ------------------------------------------------------------
# Waiting 6.29 seconds before next request...
#
# Lyrics 38/897:
# [Chorus] This song is just six words long This song is just six words long This song is just six words long This song is just six words long  [Verse 1] Couldn't think of any lyrics No, I never wrote the lyrics So, I'll just sing any old lyrics That come to mind, child  You really need words A whole ...
# Emotions: calm, tender
# ------------------------------------------------------------
# Waiting 9.62 seconds before next request...
#
# Lyrics 39/897:
# [Verse 1] I hear those ice cream bells and I start to drool Keep a couple quarts in my locker at school Yeah, but chocolate's getting old Vanilla just leaves me cold There's just one flavor good enough for me, yeah me Don't gimme no crummy taste spoon I know what I need baby  [Chorus] I love rocky r...
# Emotions: joy, obsession
# ------------------------------------------------------------
# Waiting 6.91 seconds before next request...
#
# Lyrics 40/897:
# [Intro] Happy birthday Happy birthday to you Happy birthday Happy birthday to you  [Verse 1] Well, it's time to celebrate your birthday, it happens every year We'll eat a lot of broccoli and drink a lot of beer You should be good and happy that there's something you can eat A million people every da...
# Emotions: fear, anger
# ------------------------------------------------------------
# Progress saved at song 40.
# Waiting 8.20 seconds before next request...
#
# Lyrics 41/897:
# Well, I had two weeks of vacation time coming After working all year down at 'Big Roy's Heating And Plumbing' So one night when my family and I were gathered 'round the dinner table I said, "Kids If you could go anywhere in this great big world now Where'd you like to go ta?" They said, "Dad We wann...
# Emotions: joy, hope, calm
# ------------------------------------------------------------
# Waiting 9.66 seconds before next request...
#
# Lyrics 42/897:
# [Chorus] I'm drivin' a truck Drivin' a big ol' truck Pedal to the metal, hope I don't run out of luck Rollin' down the highway until the break of dawn Drivin' a truck with my high heels on  [Verse 1] My diesel rig is northward bound It's time to put that hammer down Just watchin' as the miles go fly...
# Emotions: joy, power
# ------------------------------------------------------------
# Waiting 7.25 seconds before next request...
#
# Lyrics 43/897:
# [Verse 1] Ooh, my little hungry one, hungry one Open up a package of my bologna Ooh, I think the toast is done, the toast is done Top it with a little of my bologna  [Chorus] Never gonna stop, eat it up Such a tasty snack, I always eat too much and throw up But I'll soon be back for my, my, my-y-y, ...
# Emotions: joy, obsession
# ------------------------------------------------------------
# Waiting 6.72 seconds before next request...
#
# Lyrics 44/897:
# Charles Nelson Reilly was a mighty man The kind of man you'd never disrespect He stood eight feet tall, wore glasses And had a third nipple on the back of his neck He ate his own weight in coal, excreted diamonds everyday He could throw you down a flight of stairs But you still would love him anyway...
# Emotions: joy, power
# ------------------------------------------------------------
# Waiting 6.10 seconds before next request...
#
# Lyrics 45/897:
# [Intro] Oh, I get it! You think we're joking You think, you think we're telling a joke here This ain't no game, buddy  [Hook 1] Got people calling me a parody (Uh-huh) But no rapper compare to me (No no!) But I've had a couple swear to me "Hey yo, Cal, you're like the best MC"  [Verse 1] I swear to ...
# Emotions: power, joy
# ------------------------------------------------------------
# Waiting 8.83 seconds before next request...
#
# Lyrics 46/897:
# The white stuff, the white stuff  The first one was a sweet one Second one was a blast Soon I finished off the bag, ate 'em up real fast You can see 'em in my teeth Tell it when I talk Had so many my pancreas just went into shock  I love the white stuff, baby In the middle of an Oreo I love the whit...
# Emotions: joy, obsession
# ------------------------------------------------------------
# Waiting 9.25 seconds before next request...
#
# Lyrics 47/897:
# [Verse 1:] Fat and weak, what a disgrace Guess the champ got too lazy Ain't gonna fly now, he's just takin' up space Sold his gloves, threw his eggs down the drain But he's no bum, he works down the street He bought the neighborhood deli Back on his feet, now he's choppin' up meat Come inside, maybe...
# Emotions: calm, hope
# ------------------------------------------------------------
# Waiting 8.88 seconds before next request...
#
# Lyrics 48/897:
# [Verse 1] I starred in every high school play Blew every drama teacher away I graduated first in my class at Juilliard Took every acting workshop I could And I dreamed of Hollywood While I read my Uta Hagen and studied the Bard  [Verse 2] Hit the boards and paid my dues And got phenomenal rave revie...
# Emotions: sad, nostalgia
# ------------------------------------------------------------
# Waiting 7.23 seconds before next request...
#
# Lyrics 49/897:
# [Intro: Weird Al Yankovic] Hey girl, you know our economy's in the toilet But I'm still gonna treat you right I said you can have whatever you like (if you like) I said you can have whatever you like (if you like) Yeah, yeah  [Hook One] Tater tots, Cold Duck on ice And we can clip coupons all night ...
# Emotions: joy, hope
# ------------------------------------------------------------
# Waiting 9.98 seconds before next request...
#
# Lyrics 50/897:
# Taco Grande Taco Grande  Yo quiero chimichangas y chile colorado Yo tengo el dinero para un steak picado Las flautas y tamales, siempre muy bueno Y el chile relleno  You see, I just gotta have a tostada, carne asada That's right, I want the whole enchilada My only addiction has to do with a flour to...
# Emotions: joy, obsession
# ------------------------------------------------------------
# Progress saved at song 50.
# Waiting 9.59 seconds before next request...
#
# Lyrics 51/897:
# Faces filled with joy and cheer What a magical time of year Howdy Ho! It's Weasel Stomping Day Put your Viking helmet on Spread that mayonnaise on the lawn Don't you know it's Weasel Stomping Day? All the little girls and boys Love that wonderful crunching noise You'll know what this day's about Whe...
# Emotions: joy, power, violence
# ------------------------------------------------------------
# Waiting 6.50 seconds before next request...
#
# Lyrics 52/897:
# They see me rollin', they hatin' Patrollin' and tryin' to catch me ridin' dirty Tryin' to catch me ridin' dirty Tryin' to catch me ridin' dirty Tryin' to catch me ridin' dirty Tryin' to catch me ridin' dirty  My music's so loud, I'm swangin' They hopin' that they gon' catch me ridin' dirty Tryin' to...
# Emotions: anger, power
# ------------------------------------------------------------
# Waiting 7.44 seconds before next request...
#
# Lyrics 53/897:
# Oooh oooh oooh ee-oooh oooh oooh Ahh ahh ahh ahh ahh ahh-oooh oooh Oooooh  I'm always thinkin' 'bout it I don't know what I'd do without it I love, I really love My pancreas  My spleen just doesn't matter Don't really care about my bladder But I don't leave home without My pancreas  My pancreas is a...
# Emotions: joy, tender
# ------------------------------------------------------------
# Waiting 9.21 seconds before next request...
#
# Lyrics 54/897:
# ["Cradle of Love" by Billy Idol] Rock the cradle of love Rock the cradle of love Yes, the cradle of love Don't rock easy, it's true Rock the cradle of love I rocked the cradle of love Yes, the cradle of love Don't rock easy, it's true  ["Tom's Diner" by Susanne Vega] Doo doo doo doo doo doodooo doo ...
# Emotions: joy, sexual, power
# ------------------------------------------------------------
# Waiting 7.94 seconds before next request...
#
# Lyrics 55/897:
# [Verse 1] Down in the workshop, all the elves were making toys For the good Gentile girls and the good Gentile boys When the boss busted in, nearly scared them half to death Had a rifle in his hands and cheap whiskey on his breath From his beard to his boots, he was covered with ammo Like a big fat ...
# Emotions: violence, anger
# ------------------------------------------------------------
# Waiting 7.35 seconds before next request...
#
# Lyrics 56/897:
# [Verse 1:] There's a sale on our gabardine suits today They're all thirty percent off from yesterday There's Fortrel polyester, leather, wool and tweed Just a Visa or Mastercard is all you need  [Chorus 1:] We've got every color, we've got ev'ry shade We're located next door to Willy's Fun Arcade We...
# Emotions: joy, power
# ------------------------------------------------------------
# Waiting 8.43 seconds before next request...
#
# Lyrics 57/897:
# I want a new duck One that won't try to bite One that won't chew a hole in my socks One that won't quack all night  I want a new duck One with big webbed feet One that knows how to wash my car And keep his room real neat  One that won't raid the ice box One that'll stay in shape One that's never gon...
# Emotions: anger, power
# ------------------------------------------------------------
# Waiting 8.49 seconds before next request...
#
# Lyrics 58/897:
# [Intro] My life is brilliant... What, was I too early? I'm sorry Should I... do you wanna start over? Or keep going? Okay, now? Now?  [Verse 1] My life is brilliant Your life's a joke You're just pathetic You're always broke Your homemade Star Trek uniform Really ain't impressin' me You're sufferin'...
# Emotions: anger, power
# ------------------------------------------------------------
# Waiting 9.89 seconds before next request...
#
# Lyrics 59/897:
# Trigger happy Trigger happy  Got an AK-47, well you know it makes me feel all right Got an Uzi by my pillow, helps me sleep a little better at night There's no feeling any greater Than to shoot first and ask questions later Now I'm trigger happy, trigger happy every day  Well you can't take my guns ...
# Emotions: violence, power
# ------------------------------------------------------------
# Waiting 9.70 seconds before next request...
#
# Lyrics 60/897:
# Spam in the place where I live (ham and pork) Think about nutrition, wonder what's inside it now (oh boy) Spam in my lunchbox at work (it's the best) Really makes a darn good sandwich any way you slice it at all  If you're running low, go to the store Carry some money to help you buy more The tab is...
# Emotions: obsession, joy
# ------------------------------------------------------------
# Progress saved at song 60.
# Waiting 8.65 seconds before next request...
#
# Lyrics 61/897:
# Oh, some times I think back to when I was younger Life was so much simpler then Dad would be up at dawn He'd be watering the lawn Or maybe going fishing again  Oh, and mom would be fixing up something in the kitchen Fresh biscuits or hot apple pie And I'd spend all day long in the basement Torturing...
# Emotions: nostalgia, violence
# ------------------------------------------------------------
# Waiting 9.91 seconds before next request...
#
# Lyrics 62/897:
# [Verse 1: "Weird Al" Yankovic] You're sort of famous, a minor celebrity And so it only makes sense the world would be Obsessed with every single thing you do They're running 'round with their camcorders in the night They're lurking patiently and hoping that they just might See something real embarra...
# Emotions: anger, obsession
# ------------------------------------------------------------
# Waiting 7.83 seconds before next request...
#
# Lyrics 63/897:
# [Intro] Beautiful tats, all over my back! Makes me so proud, I'm gonna shout it out loud! I got another tattoo, baby! (Yeah!) Another tattoo, baby! (noth-noth-noth-nother tattoo, babe) Noth-nother tattoo  [Verse 1] No part of me's blank, I'm really ink obsessed It's like an art show the moment that ...
# Emotions: joy, obsession
# ------------------------------------------------------------
# Waiting 9.48 seconds before next request...
#
# Lyrics 64/897:
# You can watch Mr. Rogers You can watch Three's Company And you can turn on Fame or The Newlywed Game Or The Addams Family I say, you can watch Barney Miller And you can watch your MTV And you can watch 'till your eyes fall out of your head That'll be okay with me And you can watch (TV) You can watch...
# ⚠️ Invalid output format, retrying 1/7...
# ⚠️ Invalid output format, retrying 2/7...
# ⚠️ Invalid output format, retrying 3/7...
# ⚠️ Invalid output format, retrying 4/7...
# ⚠️ Invalid output format, retrying 5/7...
# Emotions: anger, power
# ------------------------------------------------------------
# Waiting 6.97 seconds before next request...
#
# Lyrics 65/897:
# Some girls like to buy new shoes And others like drivin' trucks and wearing tattoos There's only one thing that they all like a bunch Oh, girls, they want to have lunch Oh, girls just want to have lunch  [Crunching Noises]  I know how to keep a woman satisfied When I whip out my diner's card their e...
# Emotions: joy, sexual
# ------------------------------------------------------------
# Waiting 8.36 seconds before next request...
#
# Lyrics 66/897:
# [Verse 1] Found a job in a great big office And I really love this place I got my, my very own Scotch tape dispenser And I got a private parking space, ha And I got a coffee mug with my, with my name right on it In big bold letters so everyone knows it's mine Don't even touch it cause it doesn't bel...
# Emotions: power, joy
# ------------------------------------------------------------
# Waiting 7.61 seconds before next request...
#
# Lyrics 67/897:
# I was waiting in the express lane with my twelve items or less At the checkout counter at the local grocery store I was only passin' by but a paper caught my eye And I learned a few things I never knew before It said, "Your pet may be an extraterrestrial" It said, "The ghost of Elvis is living in my...
# ⚠️ Invalid output format, retrying 1/7...
# ⚠️ Invalid output format, retrying 2/7...
# ⚠️ Invalid output format, retrying 3/7...
# ⚠️ Invalid output format, retrying 4/7...
# ⚠️ Invalid output format, retrying 5/7...
# ⚠️ Invalid output format, retrying 6/7...
# ⚠️ Invalid output format, retrying 7/7...
# ⚠️ Failed to get valid response after 7 retries, skipping lyric.
# Emotions: error
# ------------------------------------------------------------
# Waiting 6.16 seconds before next request...
#
# Lyrics 68/897:
# I eat filet mignon seven times a day My bathtub's filled with Perrier What can I say? This is the life I buy a dozen cars when I'm in the mood I hire somebody to chew my food I'm an upwardly mobile dude This is the life  They say that money corrupts you But I can't really tell I got the whole world ...
# Emotions: power, joy
# ------------------------------------------------------------
# Waiting 8.88 seconds before next request...
#
# Lyrics 69/897:
# [Verse 1] Risin' above the city, blocking out the noonday sun It dwarfs the mighty redwoods and it towers over everyone I still remember when that delivery truck came down our block What a lucky guy, I hear he got the last one in stock And the neighbors are just green They say, "That's the biggest s...
# Emotions: joy, power
# ------------------------------------------------------------
# Waiting 9.60 seconds before next request...
#
# Lyrics 70/897:
# ["Sledgehammer" by Peter Gabriel] You could have a big dipper Going up and down around the bends You could have a bumper car bumping This amusement never ends I wanna be your sledgehammer Why don't you call my name Let me be your sledgehammer This will be my testimony, yeah, yeah yeah   ["Sussudio" ...
# ⚠️ Invalid output format, retrying 1/7...
# ⚠️ Invalid output format, retrying 2/7...
# ⚠️ Invalid output format, retrying 3/7...
# ⚠️ Invalid output format, retrying 4/7...
# ⚠️ Invalid output format, retrying 5/7...
# ⚠️ Invalid output format, retrying 6/7...
# ⚠️ Invalid output format, retrying 7/7...
# ⚠️ Failed to get valid response after 7 retries, skipping lyric.
# Emotions: error
# ------------------------------------------------------------
# Progress saved at song 70.
# Waiting 9.55 seconds before next request...
#
# Lyrics 71/897:
# [Spoken] (Damon) Here we go, here we go, here we, here we go Yo, man, Al (Albert) What's up, D? (Damon) Is school bugging you like it's bugging me? (Albert) Ooh, indubitably! (Damon) Man, I tell you, you know, it's just all these finals, i'm ready for summer, ready for the good times, the stupid rhy...
# Emotions: joy, hope
# ------------------------------------------------------------
# Waiting 8.91 seconds before next request...
#
# Lyrics 72/897:
# I don't care about your karma I don't care about what's hip No space cadet's gonna tell me what to do  I won't swim in your jacuzzi You can't make me settle down I'd rather kick and jump and bite and scratch And scream until I'm blue  I may as well be hyper as long as I'm still around Cause I'll hav...
# Emotions: anger, power
# ------------------------------------------------------------
# Waiting 8.97 seconds before next request...
#
# Lyrics 73/897:
# "Go on spit it out there is no such thing as a stupid question."  "What does your brain smell like?"  "OK now THAT'S a stupid question."  Your Brain is divided into two hemispheres Your left controls your right side and your right controls your left side And they're both tied together in a neat litt...
# Emotions: joy, calm
# ------------------------------------------------------------
# Waiting 8.14 seconds before next request...
#
# Lyrics 74/897:
# [Verse] Put down your remote control, throw out your TV guide Put away your jacket, there's no need to go outside Don't you know, that we control the horizontal We control the vertical, too We gonna make a couch potato out of you That's what we going to do now  [Chorus] Don't change the channel, don...
# Emotions: joy, power
# ------------------------------------------------------------
# Waiting 8.31 seconds before next request...
#
# Lyrics 75/897:
# Here's Johnny  There he goes, he drives me crazy When he says...(Hee-eere's Johnny!) That's his job, it's so amazing All he says is...(Hee-eere's Johnny!) I never miss a moment when he's on the tube His being there has made my life worth living The chills run down my spine Each time he says that lin...
# Emotions: joy, tender
# ------------------------------------------------------------
# Waiting 8.97 seconds before next request...
#
# Lyrics 76/897:
# Once, not very long ago, I was respected, I was popular (popular, ooh) But now I hang my head in shame (ahh, ooh) My life is filled with such regret A bad mistake I can't forget And now I'll never be the same  Ringtone Why did I buy this stupid ringtone? I just can't imagine now what I was thinking ...
# ⚠️ Invalid output format, retrying 1/7...
# ⚠️ Invalid output format, retrying 2/7...
# ⚠️ Invalid output format, retrying 3/7...
# ⚠️ Invalid output format, retrying 4/7...
# ⚠️ Invalid output format, retrying 5/7...
# ⚠️ Invalid output format, retrying 6/7...
# ⚠️ Invalid output format, retrying 7/7...
# ⚠️ Failed to get valid response after 7 retries, skipping lyric.
# Emotions: error
# ------------------------------------------------------------
# Waiting 6.14 seconds before next request...
#
# Lyrics 77/897:
# [Verse 1] I'm your shelter from the storm You know I'll always have your back I'll even let you warm Your freezing hands inside my butt crack  I never get out My leaf blower when Oprah is on When you're telling me about your feelings I try not to yawn  [Pre-Chorus] And when we're at parties I don't ...
# Emotions: tender, joy
# ------------------------------------------------------------
# Waiting 6.61 seconds before next request...
#
# Lyrics 78/897:
# Oh, Harvey, Harvey Harvey the Wonder Hamster He doesn't bite and he doesn't squeal He just runs around on his hamster wheel Harvey, Harvey Harvey the Wonder Hamster Hey, Harvey!...
# Emotions: joy, calm
# ------------------------------------------------------------
# Waiting 6.48 seconds before next request...
#
# Lyrics 79/897:
# Well, hey how ya doin' have a seat, have a drink Boy it's good to see you, what can I say? Oh, sorry gotta run we'll get together again Say, what was your name anyway?  Well we're working on the problem, we'll get back to you soon But don't try to call me I'll be in a meeting every afternoon For a y...
# Emotions: power, calm
# ------------------------------------------------------------
# Waiting 8.42 seconds before next request...
#
# Lyrics 80/897:
# Who fixes plumbing problems in a flash? Twenty-four hours a day, seven days a week?  Baby, I sure wish I could lend you a hand But plumbing's one thing I don't understand It's true (haven't got a clue) B-b-b-baby, I can tell you've got a big problem When I flush the john, then your shower goes on Ba...
# Emotions: calm, hope
# ------------------------------------------------------------
# Progress saved at song 80.
# Waiting 8.09 seconds before next request...
#
# Lyrics 81/897:
# Gotta boogie Gotta boogie Gotta boogie Gotta boogie Gotta boogie (gotta boogie) Gotta boogie (gotta boogie) Gotta boogie (gotta boogie) Gotta boogie on my finger and I can't shake it off  Well, I went out to a party just the other night I was jammin' to the music, I was feelin' alright I was burning...
# Emotions: joy, power
# ------------------------------------------------------------
# Waiting 7.93 seconds before next request...
#
# Lyrics 82/897:
# [Verse 1] Oh, I couldn't live a single day without you Actually, on second thought, well, I suppose I could Anyway, what I'm trying to say is, honey, you're the greatest Well, at any rate, I guess you're pretty good  [Verse 2] Now, it seems to me I'm relatively lucky I know I probably couldn't ask f...
# Emotions: tender, hope
# ------------------------------------------------------------
# Waiting 6.87 seconds before next request...
#
# Lyrics 83/897:
# [Verse 1] My life, it used to be incomplete Till I saw what I was looking for at a drive-in swap meet My life, it won't be the same again Now I'm proud to say the King lives on inside my den  [Pre-Chorus] Oh, it's all I live for, it's all I need  [Chorus] My velvet Elvis, my velvet Elvis My velvet E...
# Emotions: joy, obsession, power
# ------------------------------------------------------------
# Waiting 8.61 seconds before next request...
#
# Lyrics 84/897:
# I dated Siamese twins, I slept with Bigfoot, too Get me on Sally Jesse, put me on Donahue 'Cause I wanna tell the world about it right now My dog's a narcoleptic, my mom's a circus freak I gotta get a spot on Geraldo's show this week 'Cause I wanna tell the world about it right now  I'm just an anor...
# Emotions: obsession, power
# ------------------------------------------------------------
# Waiting 8.34 seconds before next request...
#
# Lyrics 85/897:
# Jillian was her name    She was sweeter than aspartame    Her kisses reconfigured my DNA    And after that I never was the same    And I loved her even more    Than Marlon Brando loved souffle    She was gorgeous, she was charming    Yeah, she was perfect in every way    Except she was always using ...
# Emotions: joy, obsession
# ------------------------------------------------------------
# Waiting 9.16 seconds before next request...
#
# Lyrics 86/897:
# I don't care if you wreck my car or shave off all my hair    You can go and run your vacuum during my favorite show    And I'll let you call up folks in Europe you don't even know    Anything you want, babe, if it makes you happy    But I'm begging you down on my bended knees    Oh, honey, please do...
# Emotions: tender, obsession
# ------------------------------------------------------------
# Waiting 6.12 seconds before next request...
#
# Lyrics 87/897:
# Risin' above the city, blocking out the noonday sun    It dwarfs the mighty redwoods and it towers over everyone    I still remember when that delivery truck came down our block    What a lucky guy, I hear he got the last one in stock    And the neighbors are just green    They say, "That's the bigg...
# Emotions: joy, power
# ------------------------------------------------------------
# Waiting 8.10 seconds before next request...
#
# Lyrics 88/897:
# George, George, George of the jungle    Strong as he can be    Ahhh    Watch out for that tree        George, George, George of the jungle    Lives a life that's free    Ahhh    Watch out for that tree        When he gets in scrapes    When he makes his escapes    With the help of his friend    An a...
# Emotions: joy, calm
# ------------------------------------------------------------
# Waiting 8.35 seconds before next request...
#
# Lyrics 89/897:
# Whoa oh        I want a new duck    One that won't try to bite    One that won't chew a hole in my socks    One that won't quack all night        I want a new duck    One with big webbed feet    One that knows how to wash my car    And keep his room real neat        One that won't raid the ice box  ...
# Emotions: obsession, power
# ------------------------------------------------------------
# Waiting 6.44 seconds before next request...
#
# Lyrics 90/897:
# It's all about the Pentiums, baby    Uhh, uh - huh, yeah    Uhh, uh - huh, yeah    It's all about the Pentiums, baby    It's all about the Pentiums, baby    It's all about the Pentiums! (It's all about the Pentiums, baby)    It's all about the Pentiums! (It's all about the Pentiums, baby)    Yeah   ...
# Emotions: power, anger
# ------------------------------------------------------------
# Progress saved at song 90.
# Waiting 8.44 seconds before next request...
#
# Lyrics 91/897:
# I got my alligator boots I wear my pants skin tight    I wear my dark sunglasses in the middle of the night    And when I look in the mirror I'm-a such an awesome sight    It makes me wanna kneel down and pray    I'm so adorable and charming I'm sure that you can see    And everyone's always trying ...
# Emotions: obsession, power
# ------------------------------------------------------------
# Waiting 6.67 seconds before next request...
#
# Lyrics 92/897:
# It's Christmas at ground zero    There's music in the air    The sleigh bells are ringing and the carolers are singing    While the air raid sirens blare    It's Christmas at ground zero    The button has been pressed    The radio just let us know that this is not a test    Everywhere the atom bombs...
# Emotions: fear, violence
# ------------------------------------------------------------
# Waiting 8.55 seconds before next request...
#
# Lyrics 93/897:
# Fun Zone doesn't really have any lyrics.    People occasionally say "yeah" and other similar phrases,    But it's generally just music.        In the movie,    It played in the background    When Stanley rode out in the miniature fire engine    At the beginning of an episode of Stanley Spadowski's C...
# ⚠️ Invalid output format, retrying 1/7...
# ⚠️ Invalid output format, retrying 2/7...
# ⚠️ Invalid output format, retrying 3/7...
# ⚠️ Invalid output format, retrying 4/7...
# ⚠️ Invalid output format, retrying 5/7...
# ⚠️ Invalid output format, retrying 6/7...
# ⚠️ Invalid output format, retrying 7/7...
# ⚠️ Failed to get valid response after 7 retries, skipping lyric.
# Emotions: error
# ------------------------------------------------------------
# Waiting 9.12 seconds before next request...
#
# Lyrics 94/897:
# There he goes, he drives me crazy    When he says...(Hee-eere's Johnny!)    That's his job, it's so amazing    All he says is...(Hee-eere's Johnny!)    I never miss a moment when he's on the tube    His being there has made my life worth living    The chills run down my spine    Each time he says th...
# Emotions: joy, tender
# ------------------------------------------------------------
# Waiting 7.12 seconds before next request...
#
# Lyrics 95/897:
# When I said that I'd be faithful    When I promised I'd be true    When I swore that I could never    Be with anyone but you    When I told you that I loved you    With those tender words I spoke    I was only kidding    Now, can't you take a joke?        When I said that I need you, baby    When I ...
# Emotions: anger, power
# ------------------------------------------------------------
# Waiting 6.10 seconds before next request...
#
# Lyrics 96/897:
# I don't care about your karma    I don't care about what's hip    No space cadet's gonna tell me what to do    I won't swim in your jacuzzi    You can't make me settle down    I'd rather kick and jump and bite and scratch    And scream until I'm blue    I may as well be hyper as long as I'm still ar...
# Emotions: anger, power
# ------------------------------------------------------------
# Waiting 7.98 seconds before next request...
#
# Lyrics 97/897:
# Met this fine young thing    At the local Circle K    We made a date for a half past eight    And I said, "What the hey?"        So I journeyed to her crib    And I let myself inside    That chick was slouched down on the couch    I think her brain was fried        Couldn't figure it out    She woul...
# Emotions: tender, joy
# ------------------------------------------------------------
# Waiting 9.33 seconds before next request...
#
# Lyrics 98/897:
# There's a sale on our gabardine suits today.    They're all thirty percent off from yesterday.    There's Fortrel polyester, leather, wool and tweed.    Just a Visa or Mastercard is all you need.    We've got every color, we've got ev'ry shade.    We're located next door to Willy's Fun Arcade.    We...
# Emotions: power, hope
# ------------------------------------------------------------
# Waiting 6.28 seconds before next request...
#
# Lyrics 99/897:
# I need a vegematic!    I need a pocket fisherman!    I need a handy appliance    That'll scramble an egg while it's still inside its shell!    (Operators are standing by.    How does that make you feel?)    Help me.    Mr. Popeil!        I wanna shine some pennies!    I wanna mend some leather!    I...
# Emotions: obsession, power
# ------------------------------------------------------------
# Waiting 9.41 seconds before next request...
#
# Lyrics 100/897:
# Krabby, Snubbull, Venonat,    Mankey, Chansey and Zubat    Slowking, Ditto, Butterfree,    Lugia and Caterpie    Oddish, Poliwag, Goldeen,    Elekid and Nidoqueen    Victreebel and Magneton - Everybody Polkamon!    Aerodactyl, Seel, Machoke,    Marill, Moltres, then Slowpoke,    Articuno, Ditto, Muk...
# Emotions: joy, hope
# ------------------------------------------------------------
# Progress saved at song 100.
# Waiting 6.80 seconds before next request...
#
# Lyrics 101/897:
# (How ya doin', Bernie?) Oy vey, oy vey!    (How ya doin', Bernie?) Oy vey, oy vey!    (How ya doin', Bernie?) Oy vey, oy vey!    (How ya doin', Bernie?) Oy vey, oy vey!    And all the goyim say I'm pretty fly for a rabbi        Meccha leccha hi, meccha hiney hiney ho        Our temple's had a fair s...
# Emotions: joy, calm
# ------------------------------------------------------------
# Waiting 8.40 seconds before next request...
#
# Lyrics 102/897:
# ...
# Progress saved at song 120.
# Waiting 7.98 seconds before next request...
#
# Lyrics 121/897:
# [Hook] I look down Out my window I see your face and your shadow On the street below me  [Verse 1] In room 34, in the third row There sits a young brother and they call him Earl-O There's a girl that Earl knows, also in the third row And he wanna flirt, so he passes her dirty notes Now she flirt bac...
# ⚠️ Rate limit hit. Retry 1/7. Waiting 1.82 seconds...
# ⚠️ Rate limit hit. Retry 2/7. Waiting 3.24 seconds...
# ⚠️ Rate limit hit. Retry 3/7. Waiting 4.93 seconds...
# ⚠️ Rate limit hit. Retry 4/7. Waiting 6.56 seconds...
# ⚠️ Rate limit hit. Retry 5/7. Waiting 63.15 seconds...
# Emotions: sad, fear
# ------------------------------------------------------------
# Waiting 7.90 seconds before next request...
#
# Lyrics 122/897:
# [Intro] Uh Uh  [Verse 1] The chosen child, came in this bitch like Colin Powell with a [?] We open now the dope is foul and leave a nigga breathing like he ran up on a mouse It's been gone a while came back now we own the aisle Seent some niggas done stole our style Over the shoulder, I hold it prou...
# ⚠️ Rate limit hit. Retry 1/7. Waiting 2.09 seconds...
# ⚠️ Rate limit hit. Retry 2/7. Waiting 2.84 seconds...
# ⚠️ Rate limit hit. Retry 3/7. Waiting 4.56 seconds...
# ⚠️ Rate limit hit. Retry 4/7. Waiting 8.42 seconds...
# ⚠️ Rate limit hit. Retry 5/7. Waiting 12.25 seconds...
# ⚠️ Rate limit hit. Retry 6/7. Waiting 16.45 seconds...
# ⚠️ Rate limit hit. Retry 7/7. Waiting 24.90 seconds...
# ⚠️ Failed to get valid response after 7 retries, skipping lyric.
# Emotions: error
# ------------------------------------------------------------
# Waiting 9.48 seconds before next request...
#
# Lyrics 123/897:
# [Intro] What if I'm not that good? What if I don't make it? What if you do make it? And what if you are that good Bobby, you'll never know until you try You've got to give it are all Bobby You've got to give it all you've got!  [Verse] Promiscuous bitches don't cover up and Epstein didn't either How...
# ⚠️ Rate limit hit. Retry 1/7. Waiting 20.24 seconds...
# ⚠️ Rate limit hit. Retry 2/7. Waiting 5.07 seconds...
# Emotions: power, hope
# ------------------------------------------------------------
# Waiting 7.78 seconds before next request...
#
# Lyrics 124/897:
# [Chorus] You ain't gotta be rich Have a lot of money like me (Yeah) Just to get my attention (Just to get my attention) I don't need your body or your trust (Oh) Just to show you who I'm fuckin' wit' (Mmm) But I need your permission (But I need your permission) You ain't gotta be rich Have a lot of ...
# ⚠️ Rate limit hit. Retry 1/7. Waiting 2.08 seconds...
# ⚠️ Rate limit hit. Retry 2/7. Waiting 3.46 seconds...
# ⚠️ Rate limit hit. Retry 3/7. Waiting 5.12 seconds...
# ⚠️ Rate limit hit. Retry 4/7. Waiting 5.68 seconds...
# ⚠️ Rate limit hit. Retry 5/7. Waiting 9.57 seconds...
# ⚠️ Rate limit hit. Retry 6/7. Waiting 16.25 seconds...
# ⚠️ Rate limit hit. Retry 7/7. Waiting 21.55 seconds...
# ⚠️ Failed to get valid response after 7 retries, skipping lyric.
# Emotions: error
# ------------------------------------------------------------
# Waiting 9.97 seconds before next request...
#
# Lyrics 125/897:
# [Intro] Best cold in the world Round three You dig? (SK) Yeah Pretty brown skin Making my heart beat Jacquees  [Verse 1] Here I go again (Yeah) Tryna get your body right, (Wha? Yeah) I always get your body right, yeah (For sure) You know we 'bout to sin (Damn) Pray the Lord forgives me for everythin...
# Emotions: sexual, joy
# ------------------------------------------------------------
# Waiting 8.95 seconds before next request...
#
# Lyrics 126/897:
# [Hook] Alhamdulillah,Alhamdulillah,Alhamdulillah Swish caught a lick Alhamdulillah,Alhamdulillah,Alhamdulillah Swish caught a lick  [Verse] I just wanna pull up in coupes I just want more foloos I just be dripping and cool I just be tripping the news Kick it with goons I just be smoking the fumes I ...
# ⚠️ Rate limit hit. Retry 1/7. Waiting 2.30 seconds...
# ⚠️ Rate limit hit. Retry 2/7. Waiting 3.21 seconds...
# ⚠️ Rate limit hit. Retry 3/7. Waiting 4.01 seconds...
# ⚠️ Rate limit hit. Retry 4/7. Waiting 59.31 seconds...
# Emotions: joy, power
# ------------------------------------------------------------
# Waiting 7.67 seconds before next request...
#
# Lyrics 127/897:
# There? not really nothing to say 28 grams to the face Now I? feeling down outta place I just like whenever I feel amazing  (Verse 1) Feeling on yo body so amazing Came up from nothin that? amazing Say what you want baby we made it Let me say thank you for nothing Mashallah we getting money Call up m...
# ⚠️ Rate limit hit. Retry 1/7. Waiting 2.38 seconds...
# ⚠️ Rate limit hit. Retry 2/7. Waiting 2.97 seconds...
# ⚠️ Rate limit hit. Retry 3/7. Waiting 4.64 seconds...
# ⚠️ Rate limit hit. Retry 4/7. Waiting 6.29 seconds...
# ⚠️ Rate limit hit. Retry 5/7. Waiting 9.49 seconds...
# ⚠️ Rate limit hit. Retry 6/7. Waiting 11.43 seconds...
# ⚠️ Rate limit hit. Retry 7/7. Waiting 43.84 seconds...
# ⚠️ Failed to get valid response after 7 retries, skipping lyric.
# Emotions: error
# ------------------------------------------------------------
# Waiting 7.38 seconds before next request...
#
# Lyrics 128/897:
# [Intro:$kinny] Yeah! Okay  [Verse 1:$kinny] I let my bitches roll my weed up They say betrayal? a fuckin' deep cut I be doping and smoking up on that green stuff with my fuckin' feet up Sippin' all that lean up(woop!) Excuse me father I have sinned I just told this little broad To come and dress me ...
# Emotions: sexual, obsession
# ------------------------------------------------------------
# Waiting 7.96 seconds before next request...
#
# Lyrics 129/897:
# [Verse] Wanna tell ya I adore ya Smoking on some California You know you are really special When I met you, you were heaven on earth  [Pre-Chorus] When I look in the stars, in your eyes I see spaceships in the skies Alone in the dark, in the night Don't be a criminal tonight  [Chorus] You're so wond...
# ⚠️ Rate limit hit. Retry 1/7. Waiting 54.10 seconds...
# Emotions: joy, tender
# ------------------------------------------------------------
# Waiting 6.99 seconds before next request...
#
# Lyrics 130/897:
# [Intro] You know we ballin' out this bitch You know we pimpin' out this motherfucker Every day a good day up in this motherfucker Cereal bowls and apple juice [?], my nigga Every day is crispy up in this motherfucker, you feel  [Hook] Every day I celebrate So high I'ma levitate Juice from the dollar...
# ⚠️ Rate limit hit. Retry 1/7. Waiting 2.03 seconds...
# ⚠️ Rate limit hit. Retry 2/7. Waiting 2.31 seconds...
# ⚠️ Rate limit hit. Retry 3/7. Waiting 5.46 seconds...
# ⚠️ Rate limit hit. Retry 4/7. Waiting 8.22 seconds...
# ⚠️ Rate limit hit. Retry 5/7. Waiting 47.70 seconds...
# ⚠️ Rate limit hit. Retry 6/7. Waiting 14.33 seconds...
# Emotions: joy, power
# ------------------------------------------------------------
# Progress saved at song 130.
# Waiting 8.92 seconds before next request...
#
# Lyrics 131/897:
# [Hook: Madonna] Life is a mystery Everyone must stand alone I hear you call my name And it feels like...  [Hook: $kinny] (All gold!) Robocop-cop Robo-robocop Robocop Robocop-cop Robo-robocop  [Verse 1: $kinny] That-that's money on my mind Why the devil keep me warm? 'Cause them angels blew my mind S...
# ⚠️ Rate limit hit. Retry 1/7. Waiting 1.79 seconds...
# ⚠️ Rate limit hit. Retry 2/7. Waiting 3.50 seconds...
# ⚠️ Rate limit hit. Retry 3/7. Waiting 5.26 seconds...
# ⚠️ Rate limit hit. Retry 4/7. Waiting 5.35 seconds...
# ⚠️ Rate limit hit. Retry 5/7. Waiting 52.18 seconds...
# ⚠️ Rate limit hit. Retry 6/7. Waiting 13.60 seconds...
# Emotions: power, obsession
# ------------------------------------------------------------
# Waiting 7.53 seconds before next request...
#
# Lyrics 132/897:
# [Skit: John Tunstall] Well, excuse me, Billy, very sorry to offend you... but we congregated here to learn to read and write. You need more than skill with a firearm to succeed in the new world, Billy. So take up the journal and start where the other boy left off, or you can go straight back to your...
# ⚠️ Rate limit hit. Retry 1/7. Waiting 2.12 seconds...
# ⚠️ Rate limit hit. Retry 2/7. Waiting 3.41 seconds...
# ⚠️ Rate limit hit. Retry 3/7. Waiting 5.17 seconds...
# ⚠️ Rate limit hit. Retry 4/7. Waiting 5.70 seconds...
# ⚠️ Rate limit hit. Retry 5/7. Waiting 11.42 seconds...
# ⚠️ Rate limit hit. Retry 6/7. Waiting 12.38 seconds...
# ⚠️ Rate limit hit. Retry 7/7. Waiting 22.90 seconds...
# ⚠️ Failed to get valid response after 7 retries, skipping lyric.
# Emotions: error
# ------------------------------------------------------------
# Waiting 6.31 seconds before next request...
#
# Lyrics 133/897:
# [Intro] Yeah (Donnie Katana), uh Who do I trust? Who do I trust? Who do I trust? Who do I, who do I trust? Who do I trust? Yeah, who do I trust? Haha Uh, Donnie, uh Who do I trust? I don't know, I don't know, you a ho Lil' ho Who do I trust? (Ricky) Yeah, uh  [Chorus] Who do I trust? I trust myself ...
# ⚠️ Rate limit hit. Retry 1/7. Waiting 31.84 seconds...
# ⚠️ Rate limit hit. Retry 2/7. Waiting 3.51 seconds...
# Emotions: anger, power
# ------------------------------------------------------------
# Waiting 8.95 seconds before next request...
#
# Lyrics 134/897:
# [Intro] Ahaha Ayy, put the volume up Alright, good, whoa, aye Yuh  [Chorus] Ayy, Samsung, Motorola, switch different phones Big choppa', small choppa', aimin' at your dome One bite, two bite, now I'm on the moon Back to the earth, chillin' in my space room Ayy, Samsung, Motorola, switch different ph...
# ⚠️ Rate limit hit. Retry 1/7. Waiting 1.74 seconds...
# ⚠️ Rate limit hit. Retry 2/7. Waiting 2.88 seconds...
# ⚠️ Rate limit hit. Retry 3/7. Waiting 4.48 seconds...
# ⚠️ Rate limit hit. Retry 4/7. Waiting 6.86 seconds...
# ⚠️ Rate limit hit. Retry 5/7. Waiting 10.21 seconds...
# ⚠️ Rate limit hit. Retry 6/7. Waiting 14.12 seconds...
# ⚠️ Rate limit hit. Retry 7/7. Waiting 25.05 seconds...
# ⚠️ Failed to get valid response after 7 retries, skipping lyric.
# Emotions: error
# ------------------------------------------------------------
# Waiting 7.53 seconds before next request...
#
# Lyrics 135/897:
# [Intro] Ayy, Lee, grab my Veneta sandals Ahem Yuh Ayy  [Verse] I grab my Veneta sandals then I'ma hop to the sto' I ask my niggas, "What you want? 'Cause I'ma get me some clothes" They said, "I want me Saint Laurent and some vintage Dior" I said, "Fuck you niggas, I'ma get me vintage Dior" 'Cause ai...
# ⚠️ Rate limit hit. Retry 1/7. Waiting 26.19 seconds...
# ⚠️ Rate limit hit. Retry 2/7. Waiting 3.17 seconds...
# Emotions: power, obsession
# ------------------------------------------------------------
# Waiting 8.19 seconds before next request...
#
# Lyrics 136/897:
# [Intro] Ayy, you know sometimes I be, I be shaking Sometimes it's, it's with my demons and shit, you know? Yeah  [Chorus] Ayy, I shake, I shackle (Why?) I battle all my demons (Why?) In the mornin' I be fiendin' (Damn) In the sleepin' I be dreamin' (Why?) What you know about this sadness? (What?) Ev...
# ⚠️ Rate limit hit. Retry 1/7. Waiting 1.70 seconds...
# ⚠️ Rate limit hit. Retry 2/7. Waiting 2.78 seconds...
# ⚠️ Rate limit hit. Retry 3/7. Waiting 4.78 seconds...
# ⚠️ Rate limit hit. Retry 4/7. Waiting 5.40 seconds...
# ⚠️ Rate limit hit. Retry 5/7. Waiting 11.51 seconds...
# ⚠️ Rate limit hit. Retry 6/7. Waiting 15.39 seconds...
# ⚠️ Rate limit hit. Retry 7/7. Waiting 22.72 seconds...
# ⚠️ Failed to get valid response after 7 retries, skipping lyric.
# Emotions: error
# ------------------------------------------------------------
# Waiting 9.02 seconds before next request...
#
# Lyrics 137/897:
# [Intro] Chill Bwser, chill Go  [Chorus] Hmm-hmm, hmm (Go) In a bulletproof black Tahoe We gon' box 'em up wholesale like it's Costco Dash like I'm Roscoe Fuckin' on your ho, we the Bang Bros (Woo) This a Glock, we don't even name bro We is not the same bro (Huh) Open up your eyes, let 'em inside Eve...
# ⚠️ Rate limit hit. Retry 1/7. Waiting 36.37 seconds...
# Emotions: anger, violence, power
# ------------------------------------------------------------
# Waiting 7.30 seconds before next request...
#
# Lyrics 138/897:
# [Intro: $NOT] Ayy, man, thanks for changing but I'm still on the same shit You feel me? Hahaha Sauron Ayy  [Verse 1: $NOT] I wake up and brush my teeth, Nike shoes and Polo tee Ride my bike up out the streets, fuck with me, I'll fuck wit' you That's not where you s'posed to be, smokin' on this Backw...
# ⚠️ Rate limit hit. Retry 1/7. Waiting 2.34 seconds...
# ⚠️ Rate limit hit. Retry 2/7. Waiting 2.59 seconds...
# ⚠️ Rate limit hit. Retry 3/7. Waiting 3.64 seconds...
# ⚠️ Rate limit hit. Retry 4/7. Waiting 7.98 seconds...
# ⚠️ Rate limit hit. Retry 5/7. Waiting 10.43 seconds...
# ⚠️ Rate limit hit. Retry 6/7. Waiting 14.98 seconds...
# ⚠️ Rate limit hit. Retry 7/7. Waiting 19.05 seconds...
# ⚠️ Failed to get valid response after 7 retries, skipping lyric.
# Emotions: error
# ------------------------------------------------------------
# Waiting 7.97 seconds before next request...
#
# Lyrics 139/897:
# [Intro] Yeah (Keep that, Paryo) Woah, oh  [Chorus] Made it out the city with my slime Fuckin' up a check and then I slide You ain't met no one that do it like me You ain't met no one that do it like me Fuckin' with me I might break your heart Superstar riding fancy cars You ain't met no one that do ...
# ⚠️ Rate limit hit. Retry 1/7. Waiting 4.11 seconds...
# Emotions: power, joy
# ------------------------------------------------------------
# Waiting 9.47 seconds before next request...
#
# Lyrics 140/897:
# [Intro] Yeah (Keep that, Paryo) Woah, oh  [Chorus] Made it out the city with my slime Fuckin' up a check and then I slide You ain't met no one that do it like me You ain't met no one that do it like me Fuckin' with me I might break your heart Superstar riding fancy cars You ain't met no one that do ...
# ⚠️ Rate limit hit. Retry 1/7. Waiting 2.44 seconds...
# ⚠️ Rate limit hit. Retry 2/7. Waiting 3.60 seconds...
# ⚠️ Rate limit hit. Retry 3/7. Waiting 58.71 seconds...
# Emotions: power, joy
# ------------------------------------------------------------
# Progress saved at song 140.
# Waiting 7.21 seconds before next request...
#
# Lyrics 141/897:
# [Intro: $NOT] (Yung Castor) Ayy, bitch, I'll take you to the fuckin' (Ayy, uh) I'll take you to the fuckin' moon and stars You feel me? (Yeah) Hahaha (Ayy, ayy)  [Chorus: $NOT] Okay, I hop up in my coupe, yeah (Wassup?) Wassup? Do you wanna go far with me? (With me) Hold my hand, I ain't really goin...
# ⚠️ Rate limit hit. Retry 1/7. Waiting 1.57 seconds...
# ⚠️ Rate limit hit. Retry 2/7. Waiting 2.34 seconds...
# ⚠️ Rate limit hit. Retry 3/7. Waiting 3.67 seconds...
# ⚠️ Rate limit hit. Retry 4/7. Waiting 5.21 seconds...
# ⚠️ Rate limit hit. Retry 5/7. Waiting 7.72 seconds...
# ⚠️ Rate limit hit. Retry 6/7. Waiting 12.32 seconds...
# ⚠️ Rate limit hit. Retry 7/7. Waiting 18.16 seconds...
# ⚠️ Failed to get valid response after 7 retries, skipping lyric.
# Emotions: error
# ------------------------------------------------------------
# Waiting 8.34 seconds before next request...
#
# Lyrics 142/897:
# [Intro: Criggy Dah Pissay] Bitch, I am Gorilla da Spinna [?] on the beat (Orangatangabangin) All y'all hatin' on me, I'm 'bout to come up And all the people that's supportin', they 'bout to come with me All my lil' Goonz, let's get it  [Verse 1: Criggy Dah Pissay] What it is? Who it be? It be Criggy...
# ⚠️ Rate limit hit. Retry 1/7. Waiting 38.49 seconds...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 122
#     119 lyrics = row["lyrics"]
#     120 print(f"\nLyrics {i+1}/{len(df)}:\n{lyrics[:300]}...")
# --> 122 emotions = get_lyrics_emotions(lyrics)
#     123 df.at[i, "emotions"] = emotions
#     125 print("Emotions:", emotions)
#
# Cell In[12], line 93, in get_lyrics_emotions(lyrics, max_retries)
#      91     sleep_time = max(wait_time, backoff) * jitter
#      92     print(f"⚠️ Rate limit hit. Retry {retries}/{max_retries}. Waiting {sleep_time:.2f} seconds...")
# ---> 93     time.sleep(sleep_time)
#      94     backoff = min(backoff * 1.5, 30)
#      96 else:
#
# KeyboardInterrupt:

# %%
import pandas as pd
import requests
import time
import random
import re

api_key = "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"

headers = {
    "Authorization": f"Bearer {api_key}",
    "Content-Type": "application/json"
}

EMOTION_LIST = ["joy", "anger", "fear", "nostalgia", "sad", "obsession", "sexual", "hope", "calm", "tender", "violence", "power"]
EMOTION_SET = set(EMOTION_LIST)

def extract_emotions_only(text):
    found = re.findall(r'\b(?:' + '|'.join(EMOTION_LIST) + r')\b', text.lower())
    found = list(dict.fromkeys(found))  # deduplicate, preserve order
    if 2 <= len(found) <= 4:
        return ', '.join(found)
    else:
        return "error"

def is_valid_emotion_output(output):
    emotions = [e.strip() for e in output.lower().split(",")]
    return 2 <= len(emotions) <= 4 and all(e in EMOTION_SET for e in emotions)

def get_lyrics_emotions(lyrics, max_retries=7):
    prompt = f"""
Given the following song lyrics, label them with the most dominant emotions.
Use only the following emotion labels: joy, anger, fear, nostalgia, sad, obsession, sexual, hope, calm, tender, violence, power.
Return the emotions separated by commas. The number of labels must be 2 to 4.
Do not provide any explanation. Only return the emotion labels.

Lyrics:
{lyrics}

Emotions:
"""
    data = {
        "model": "llama3-70b-8192",
        "messages": [{"role": "user", "content": prompt}],
        "temperature": 0.2
    }

    backoff = 10  # Start with 10s backoff
    retries = 0

    while retries < max_retries:
        try:
            response = requests.post(
                "https://api.groq.com/openai/v1/chat/completions",
                headers=headers,
                json=data
            )
            if response.status_code == 200:
                raw_output = response.json()["choices"][0]["message"]["content"].strip()
                extracted = extract_emotions_only(raw_output)
                if extracted != "error" and is_valid_emotion_output(extracted):
                    return extracted
                else:
                    retries += 1
                    print(f"⚠️ Invalid output format, retrying {retries}/{max_retries}...")
                    time.sleep(random.uniform(3, 5))
                    continue

            elif response.status_code == 429:
                retries += 1
                try:
                    msg = response.json()["error"]["message"]
                    wait_time = float(msg.split("try again in ")[1].split("s")[0])
                except Exception:
                    wait_time = backoff

                jitter = random.uniform(1.0, 1.5)
                sleep_time = max(wait_time, backoff) * jitter
                print(f"⚠️ Rate limit hit. Retry {retries}/{max_retries}. Waiting {sleep_time:.2f} seconds...")
                time.sleep(sleep_time)
                backoff = min(backoff * 1.5, 60)  # Cap at 60s

            else:
                print(f"❌ API error {response.status_code}: {response.text}")
                return "error"

        except Exception as e:
            print(f"❌ Request failed: {e}")
            retries += 1
            time.sleep(backoff)
            backoff = min(backoff * 1.5, 60)

    print(f"⚠️ Failed to get valid response after {max_retries} retries. Skipping lyric.")
    return "error"

# Load CSV
df = pd.read_csv("good.csv", encoding='ISO-8859-1')

if 'lyrics' not in df.columns:
    raise ValueError("CSV must have a column named 'lyrics'.")

if "emotions" not in df.columns:
    df["emotions"] = ""

# Loop over rows
for i, row in df.iterrows():
    lyrics = row["lyrics"]
    print(f"\nLyrics {i+1}/{len(df)}:\n{lyrics[:300]}...")

    emotions = get_lyrics_emotions(lyrics)
    df.at[i, "emotions"] = emotions

    print("Emotions:", emotions)
    print("-" * 60)

    # Save progress after every lyric to avoid data loss
    df.to_csv("labeled_lyrics_progress.csv", index=False)
    print(f"✅ Progress saved at song {i+1}.")

    # Delay between requests (longer to avoid rate limits)
    delay = random.uniform(12, 20)
    print(f"⏳ Waiting {delay:.2f} seconds before next request...")
    time.sleep(delay)

# Final save
df.to_csv("labeled_lyrics_final.csv", index=False)
print("\n✅ Done! Emotions labeled and saved to labeled_lyrics_final.csv")
# Out:
# Lyrics 1/897:
# Oh my god, did I just say that out loud? Should've known this was the kind of place That that sort of thing just wasn't allowed Should've known by the color of the drapes (Oh, my bad, venetian blinds) What the hell was I thinking saying exactly what's on my mind? But I won't deny I got a dirty mouth...
# C:\Users\LAPTOP INSIDE\AppData\Local\Temp\ipykernel_12604\2861477570.py:110: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'anger, power' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[i, "emotions"] = emotions
# Emotions: anger, power
# ------------------------------------------------------------
# ✅ Progress saved at song 1.
# ⏳ Waiting 18.89 seconds before next request...
#
# Lyrics 2/897:
# [Verse 1] Remember when I called you on the telephone? You were so far away It was raining in New York, did I forget to say? It was later than I wanted it to be On an early summer's night The kind where you can't help but feel alive and free And I told you "From here on out, it's just you and me"  [...
# ⚠️ Rate limit hit. Retry 1/7. Waiting 65.94 seconds...
# Emotions: hope, joy, tender
# ------------------------------------------------------------
# ✅ Progress saved at song 2.
# ⏳ Waiting 14.99 seconds before next request...
#
# Lyrics 3/897:
# [Verse 1] Calling me like I got something to say You thought wrong, but you do it anyway How's it been? Oh, not much, same for me, please go away I can put it on if that's what you want You'd like to get together, but I'd rather not Calls to mind a simpler time that who gave a shit forgot  [Pre-Chor...
# ⚠️ Rate limit hit. Retry 1/7. Waiting 13.18 seconds...
